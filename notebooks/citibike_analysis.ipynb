# %% [markdown]
# # Classifying Commuter vs. Recreational Citi Bike Trips
# ### What Trip Features Predict Ride Purpose in New York City?
#
# **Programming Tools for Urban Analytics** | Dr Qunshan Zhao
# **Deadline:** 30 March 2026
#
# ---
#
# ## Section 0 — Setup
# Run this cell first. It imports all libraries and opens the DuckDB connection.

# %%
import os, sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import numpy as np
import pandas as pd
import duckdb
import requests

import geopandas as gpd
import folium
from shapely.geometry import Point

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.dpi'] = 120
sns.set_theme(style='whitegrid', palette='muted')

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import StandardScaler
import shap

from dotenv import load_dotenv
from tqdm import tqdm
import holidays

from src.utils import DATA_RAW, DATA_PRO, DB_PATH, log
load_dotenv()

con = duckdb.connect(str(DB_PATH))
print(f'DuckDB connected: {DB_PATH}')
print(f'Pandas {pd.__version__} | DuckDB {duckdb.__version__}')

# %% [markdown]
# ---
# ## Section 1 — Introduction
#
# *(~400 words — write your report introduction here)*
#
# **Research question:** *What trip-level features best predict whether a Citi Bike journey is made for commuting or recreational purposes, and what does the spatial and temporal distribution of classified trips reveal about urban mobility patterns in New York City?*

# %% [markdown]
# ---
# ## Section 2 — Data Collection
#
# *(~350 words)*

# %%
from src.data_download import (
    download_citibike_trips,
    fetch_gbfs_stations,
    fetch_weather_history,
    download_pluto
)

# %% [markdown]
# ---
# ## Section 3 — Data Understanding

# %% [markdown]
# ---
# ## Section 4 — Data Cleaning

# %% [markdown]
# ---
# ## Section 5 — Proxy Label Construction

# %% [markdown]
# ---
# ## Section 6 — Feature Engineering

# %% [markdown]
# ---
# ## Section 7 — Modelling

# %% [markdown]
# ---
# ## Section 8 — Interpretability & Spatial Analysis

# %% [markdown]
# ---
# ## Section 9 — Discussion & Policy Implications
#
# *(~450 words)*

# %% [markdown]
# ---
# ## References
#
# - Breiman, L. (2001). Random forests. *Machine Learning*, 45(1), 5-32.
# - Chen, T. & Guestrin, C. (2016). XGBoost. *Proc. KDD*, 785-794.
# - Fishman, E., Washington, S. & Haworth, N. (2014). Bike share's impact on car use. *Transportation Research Part D*, 31, 13-20.
# - Lundberg, S. & Lee, S. (2017). A unified approach to interpreting model predictions. *NeurIPS*, 30.
# - Ursaki, J. & Aultman-Hall, L. (2015). Quantifying the equity of bikeshare access. *Transportation Research Record*, 2512(1), 28-38.
# - Xing, Y. et al. (2020). Exploring travel patterns of dockless bike-sharing. *Journal of Transport Geography*, 87.
